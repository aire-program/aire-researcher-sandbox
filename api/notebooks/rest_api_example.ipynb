# %% [markdown]
# # REST API Example
#
# Demonstrates usage of the mock REST API client.

# %%
import sys
import os

if 'google.colab' in sys.modules:
    # !git clone https://github.com/YOUR_USERNAME/aire-researcher-sandbox.git
    # %cd aire-researcher-sandbox

sys.path.append(os.getcwd())
from api.python.client_rest_api import ResearchAPIClient

client = ResearchAPIClient()
print(client.get_status())
print(client.get_projects())
