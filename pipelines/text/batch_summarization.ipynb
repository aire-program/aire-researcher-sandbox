# %% [markdown]
# # Batch Summarization
#
# Simulates batch summarization of articles.

# %%
import sys
import pandas as pd

if 'google.colab' in sys.modules:
    # !pip install -q pandas
    # !git clone https://github.com/YOUR_USERNAME/aire-researcher-sandbox.git
    # %cd aire-researcher-sandbox

df = pd.read_csv('data/sample_texts/articles_sample.csv')
df['summary'] = df['abstract'].apply(lambda x: x[:50] + "..." if isinstance(x, str) else "")
display(df[['title', 'summary']].head())
