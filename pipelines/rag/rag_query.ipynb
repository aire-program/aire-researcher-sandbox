# %% [markdown]
# # RAG Query
#
# This notebook queries the built index.

# %%
import sys
import os
import pickle
from sklearn.metrics.pairwise import cosine_similarity

# Colab Setup
if 'google.colab' in sys.modules:
    # !pip install -q pandas numpy scikit-learn
    if not os.path.exists('aire-researcher-sandbox'):
        # !git clone https://github.com/YOUR_USERNAME/aire-researcher-sandbox.git
    # %cd aire-researcher-sandbox

# %%
if os.path.exists('tfidf_index.pkl'):
    with open('tfidf_index.pkl', 'rb') as f:
        vectorizer, tfidf_matrix, df = pickle.load(f)
    
    query = "neural networks"
    query_vec = vectorizer.transform([query])
    scores = cosine_similarity(query_vec, tfidf_matrix).flatten()
    
    top_idx = scores.argsort()[-3:][::-1]
    for idx in top_idx:
        print(f"Score: {scores[idx]:.4f} | Title: {df.iloc[idx]['title']}")
else:
    print("Index not found. Run build_index.ipynb first.")
